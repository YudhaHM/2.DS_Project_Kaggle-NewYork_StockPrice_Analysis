# %% [markdown]
# # 1. Loading New York Stock Price and Fundamental Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fundamentals = pd.read_csv('fundamentals.csv', index_col=0)
prices = pd.read_csv('prices.csv')
prices2 =pd.read_csv('prices-split-adjusted.csv')
securities = pd.read_csv('securities.csv')

# %%
fundamentals
# Out:
#      Ticker Symbol Period Ending  Accounts Payable  Accounts Receivable  \
# 0              AAL    2012-12-31      3.068000e+09         -222000000.0
# 1              AAL    2013-12-31      4.975000e+09          -93000000.0
# 2              AAL    2014-12-31      4.668000e+09         -160000000.0
# 3              AAL    2015-12-31      5.102000e+09          352000000.0
# 4              AAP    2012-12-29      2.409453e+09          -89482000.0
# ...            ...           ...               ...                  ...
# 1776          ZION    2015-12-31      0.000000e+00                  0.0
# 1777           ZTS    2013-12-31      1.381000e+09          -99000000.0
# 1778           ZTS    2014-12-31      1.071000e+09           69000000.0
# 1779           ZTS    2015-12-31      1.313000e+09          -58000000.0
# 1780           ZTS    2016-12-31      1.076000e+09           15000000.0
#
#       Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# ...

# %%
prices2
# Out:
#               date symbol        open       close         low        high  \
# 0       2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1       2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2       2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3       2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4       2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
# ...            ...    ...         ...         ...         ...         ...
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#            volume
# 0       2163600.0
# 1       2386400.0
# 2       2489500.0
# ...

# %% [markdown]
# # 2. Analyze Data

# %%
fundamentals.columns
# Out:
# Index(['Ticker Symbol', 'Period Ending', 'Accounts Payable',
#        'Accounts Receivable', 'Add'l income/expense items', 'After Tax ROE',
#        'Capital Expenditures', 'Capital Surplus', 'Cash Ratio',
#        'Cash and Cash Equivalents', 'Changes in Inventories', 'Common Stocks',
#        'Cost of Revenue', 'Current Ratio', 'Deferred Asset Charges',
#        'Deferred Liability Charges', 'Depreciation',
#        'Earnings Before Interest and Tax', 'Earnings Before Tax',
#        'Effect of Exchange Rate',
#        'Equity Earnings/Loss Unconsolidated Subsidiary', 'Fixed Assets',
#        'Goodwill', 'Gross Margin', 'Gross Profit', 'Income Tax',
#        'Intangible Assets', 'Interest Expense', 'Inventory', 'Investments',
#        'Liabilities', 'Long-Term Debt', 'Long-Term Investments',
#        'Minority Interest', 'Misc. Stocks', 'Net Borrowings', 'Net Cash Flow',
#        'Net Cash Flow-Operating', 'Net Cash Flows-Financing',
# ...

# %%
fundamentals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1781 entries, 0 to 1780
# Data columns (total 78 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Ticker Symbol                                        1781 non-null   object
#  1   Period Ending                                        1781 non-null   object
#  2   Accounts Payable                                     1781 non-null   float64
#  3   Accounts Receivable                                  1781 non-null   float64
#  4   Add'l income/expense items                           1781 non-null   float64
#  5   After Tax ROE                                        1781 non-null   float64
#  6   Capital Expenditures                                 1781 non-null   float64
#  7   Capital Surplus                                      1781 non-null   float64
# ...

# %%
fundamentals.isna().sum()
# Out:
# Ticker Symbol                     0
# Period Ending                     0
# Accounts Payable                  0
# Accounts Receivable               0
# Add'l income/expense items        0
#                                ...
# Total Revenue                     0
# Treasury Stock                    0
# For Year                        173
# Earnings Per Share              219
# Estimated Shares Outstanding    219
# Length: 78, dtype: int64

# %%
prices2.columns
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
prices2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    851264 non-null  object
#  1   symbol  851264 non-null  object
#  2   open    851264 non-null  float64
#  3   close   851264 non-null  float64
#  4   low     851264 non-null  float64
#  5   high    851264 non-null  float64
#  6   volume  851264 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
prices2['date'].str[0:4].unique()
# Out:
# array(['2016', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype=object)

# %%
prices2['symbol'].unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
# ...

# %% [markdown]
# ## Apple (AAL) Stock Analysis Data

# %%
plt.figure(figsize=(15,5))
days = [2010,2011,2012,2013,2014,2015,2016]
plt.plot(prices2[prices2['symbol'] == "AAL"].close.values)
plt.xlabel('Total Days')
plt.ylabel("Stock Price")
# Out:
# Text(0, 0.5, 'Stock Price')

# %%
plt.figure(figsize=(15,5))
days = [2010,2011,2012,2013,2014,2015,2016]
plt.plot(prices2[prices2['symbol'] == "AAL"].date.str[0:7], prices2[prices2['symbol'] == "AAL"].close.values)
plt.xlabel('Total Days')
plt.ylabel("Stock Price")
# Out:
# Text(0, 0.5, 'Stock Price')

# %% [markdown]
# ## Google (GOOG) Stock Analysis Data

# %%
plt.figure(figsize=(15,5))
plt.plot(prices2[prices2['symbol'] == "GOOG"].close.values)
plt.xlabel('Total Days')
plt.ylabel("Stock Price")
# Out:
# Text(0, 0.5, 'Stock Price')

# %% [markdown]
# # Manipulate Data

# %%
prices2.loc[(prices2['date'] == '2016-01-05') | (prices2['date'] == '2016-12-30') ]
# Out:
#               date symbol        open       close         low        high  \
# 0       2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 250     2016-12-30   WLTW  122.589996  122.279999  121.389999  123.559998
# 725889  2016-01-05      A   40.730000   40.549999   40.340000   40.950001
# 725890  2016-01-05    AAL   41.180000   40.520000   39.950001   41.490002
# 725891  2016-01-05    AAP  152.350006  151.199997  149.889999  153.789993
# ...            ...    ...         ...         ...         ...         ...
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#             volume
# 0        2163600.0
# 250       466400.0
# ...

# %%
# Out:
# array(['2016', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype=object)
